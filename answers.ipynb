# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./train.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Question 1
df.head(6)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
# Question 2
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
# Question 3
print('Number of Passengers: ' + str(len(df)))
# Out:
# Number of Passengers: 891

# %%
# Question 4
df[['Age', 'Cabin', 'Embarked']].isnull().sum()
# Out:
# Age         177
# Cabin       687
# Embarked      2
# dtype: int64

# %%
# Question 5
df['Embarked'].value_counts().plot(kind='pie', autopct='%1.1f%%', figsize=(5, 5), title='Embarked')
# Most people embarked from Southampton
# Least people embarked from Queenstown
# Out:
# <AxesSubplot: title={'center': 'Embarked'}, ylabel='Embarked'>

# %%
# Question 6
df['Pclass'].value_counts().plot(kind='bar', title='Pclass')
#Third class has the most number of passengers
# Out:
# <AxesSubplot: title={'center': 'Pclass'}>

# %%
# Question 7
df[df['Sex'] == 'female'].groupby(['Sex', 'Survived'])['Pclass'].value_counts().plot(kind='bar', title='Survived')
# Out:
# <AxesSubplot: title={'center': 'Survived'}, xlabel='Sex,Survived,Pclass'>

# %%
# Question 8
df.boxplot(column='Age', by=['Survived', 'Sex'], figsize=(10, 10))
# Out:
# <AxesSubplot: title={'center': 'Age'}, xlabel='[Survived, Sex]'>

# %%
# Question 9
pd.crosstab(df['Sex'], df['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
# Question 11
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(6,6)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17028\1348284034.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)

# %%
# Question 12
sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)
fig=plt.gcf()
fig.set_size_inches(6,6)
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_17028\4251877807.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='RdYlGn', linewidths=0.2)

# %%
# Question 13
df['Age'].min()
# Out:
# 0.42

# %%
# Question 14
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
# Question 15
df[df['Survived']==1]['Age'].max()
# Out:
# 80.0

# %%
# Question 16
df[(df['Survived']==1) & (df['Sex']=='female')]['Age'].max()
# Out:
# 63.0

# %%
# Question 17
df[(df['Age']<10) & (df['Parch']==0)]
# There may be intruders
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 777          778         1       3  Emanuel, Miss. Virginia Ethel  female
#
#      Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 777  5.0      0      0  364516  12.475   NaN        S

# %%
# Question 18

# %%
# Question 19
df['SibSp'].max()
# Out:
# 8

# %%
# Question 20
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=df)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Fare'>
